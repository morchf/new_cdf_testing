# %%
import h3
from pyspark.sql import SparkSession
from pyspark.sql import Window
from pyspark.sql.functions import col, lit, udf, acos, cos, sin, radians, rank, element_at
from pyspark.sql.types import StringType, FloatType, BooleanType, ArrayType, DoubleType
import pandas as pd

# %%
import os
import data_preparation_faster
from data_preparation_faster import prepare_triplogs, prepare_tripdatas, get_clean_triplogs, get_clean_tripdatas

# %%
data_dir = "../2020_11_8_to_2020_11_14"

# %%
# !ls ../2020_11_8_to_2020_11_14/CMS
# Out:
# intersectionstatusreport.csv
# intersectionstatusreport_data_dictionary.docx
# opticomdevicelog.csv
# opticomdevicelog_data_dictonary.docx

# %%
tripdatas_df = pd.read_csv(os.path.join(data_dir, "CVP/tripdatas.csv"))

# %%
triplogs_df = pd.read_csv(os.path.join(data_dir, "CVP/triplogs.csv"))

# %%
triplogs_df = prepare_triplogs(triplogs_df)
tripdatas_df = prepare_tripdatas(tripdatas_df)

# takes about 4 minutes to run

tripdatas_df = get_clean_tripdatas(tripdatas_df) # cleaning tripdatas first is important
tripdatas_df_good = tripdatas_df[tripdatas_df["is_good_for_study"]]
triplogs_df = get_clean_triplogs(triplogs_df, tripdatas_df_good)
triplogs_df_good = triplogs_df[triplogs_df["is_good_for_study"]]
# Out:
# drop invalid
# drop starttime >= endtime
# drop endstatus not completed
# drop normal tspmode
# drop negative duration
# drop <=70% stops hit
# drop <=70% breadcrumbs
# drop duplicated rows
# drop tspon no tsp requests
# drop 3 stds anomalies

# %%
intersection_status_report_df = pd.read_csv(os.path.join(data_dir, "CMS/intersectionstatusreport.csv"))

# %%
triplogs_df_good[["is_good_for_study"]].head()
# Out:
#     is_good_for_study
# 1                True
# 3                True
# 4                True
# 5                True
# 14               True

# %%
import os

# %%
def dist(lat_x, long_x, lat_y, long_y):
    return acos(
        sin(radians(lat_x)) * sin(radians(lat_y)) +
        cos(radians(lat_x)) * cos(radians(lat_y)) *
            cos(radians(long_x) - radians(long_y))
    ) * lit(6371.0 * 1000) # in meters

# %%
import math 

def dist_simple(lat_x, long_x, lat_y, long_y):
    # no spark used here
    return math.acos(
        math.sin(math.radians(lat_x)) * math.sin(math.radians(lat_y)) +
        math.cos(math.radians(lat_x)) * math.cos(math.radians(lat_y)) *
            math.cos(math.radians(long_x) - math.radians(long_y))
    ) * 6371.0 * 1000 # in meters

# %%
geo_to_h3_udf = udf(h3.geo_to_h3, StringType())

# %%
spark = SparkSession \
    .builder \
    .master("local[*]") \
    .config('spark.driver.memory','3G') \
    .getOrCreate()

# %%
# old read

# %%
# intersection_status_report = spark.read.parquet("./source/intersection_status_report/2021-05-01")

# %%
# trip_logs = spark.read.parquet("./source/triplogs/05-01-2021").drop('routeName')

# %%
# trip_datas = spark.read.parquet("./source/tripdatas/05-01-2021")

# %%
####

# %%
# new read

# %%
intersection_status_report_df[['latitude', 'longitude']] = intersection_status_report_df[['latitude', 'longitude']].astype(str)

# %%
intersection_status_report_df.columns
# Out:
# Index(['deviceid', 'locationid', 'locationname', 'device',
#        'applicationfirmwareversion', 'lastlogretrieved', 'latitude',
#        'longitude', 'cha', 'chb', 'chc', 'chd', 'status', 'details',
#        'date_ran'],
#       dtype='object')

# %%
intersection_status_report_df = intersection_status_report_df[['status','locationid', 'locationname', 'latitude', 'longitude']]

# %%
intersection_status_report = spark.createDataFrame(intersection_status_report_df)

# %%
trip_logs = spark.createDataFrame(triplogs_df_good[['deviceid', 'direction', 'duration', 'logid', 'routename', 'tripid', 'tspmode', 'uid', 'is_good_for_study']])

# %%
del tripdatas_df

# %%
tripdatas_df_good[['deviceid',
       'event', 'loc', 'logid', 'mph', 'routename',
       'stopname', 'time', 'date_ran',
       'uid', 'is_good_for_study']].to_parquet("tripdatas_df_good_pq")

# %%
trip_datas = spark.read.parquet("tripdatas_df_good_pq")

# %%
del tripdatas_df_good
del triplogs_df
del triplogs_df_good

# %%
trip_datas = trip_datas \
    .withColumnRenamed('logid', 'logID') \
    .withColumnRenamed('deviceid', 'deviceID')

trip_logs = trip_logs \
    .withColumnRenamed('logid', 'logID') \
    .withColumnRenamed('deviceid', 'deviceID').drop('routename')

# %%
####

# %%
trip_log_datas = trip_logs.join(trip_datas, on=['logID', 'deviceID'], how='inner')

# %%
intersections = intersection_status_report \
    .filter("status <> 'Error'") \
    .withColumnRenamed('latitude', 'actual_lat') \
    .withColumnRenamed('longitude', 'actual_lon') \
    .withColumnRenamed('locationname', 'name') \
    .withColumnRenamed('locationid', 'id') \
    .withColumn('actual_lat', col('actual_lat').cast("double")) \
    .withColumn('actual_lon', col('actual_lon').cast("double")) \
    .withColumn('zone_id', geo_to_h3_udf('actual_lat', 'actual_lon', lit(9))) \
    .select('id', 'name', 'actual_lat', 'actual_lon', 'zone_id') \
    .distinct()

# %%
def loc_to_coords(loc):
    coords = [float(x) for x in loc[loc.index('[') + 1: loc.index(']')].split(',')]
    return coords

loc_to_coords_udf = udf(loc_to_coords, ArrayType(DoubleType()))

# %%
from pyspark.sql.functions import row_number

trip_log_datas = trip_log_datas \
    .withColumn('loc_coords', loc_to_coords_udf('loc'))

zoned_trip_data = trip_log_datas \
    .withColumnRenamed('tspMode','tspmode') \
    .withColumnRenamed('routeName', 'routename') \
    .withColumn('lon', element_at(col("loc_coords"), 1)) \
    .withColumn('lat', element_at(col("loc_coords"), 2)) \
    .select('lon', 'lat', 'time', 'routeName', 'direction', 'tripID', 'logID', 'deviceID', 'event', 'mph', 'tspMode') \
    .withColumn('zone_id', geo_to_h3_udf('lat', 'lon', lit(9))) \
    .withColumn('breadcrumb_index', row_number().over(Window.partitionBy(['logID', 'deviceID']).orderBy('time')))

# %% [markdown]
# ## Detect tripdatas closest to intersection (tripdata points crossing intersection)

# %%
# max distance (m) from breadcrumb to intersection, bus to be considered possibly crossing this intersection
# it can be thought of as a gps sideways threshold
dist_to_be_crossing_thresh = 45

# %%
zoned_trip_data_intersection = zoned_trip_data.join(intersections, on="zone_id")

zoned_trip_data_intersection = zoned_trip_data_intersection \
    .withColumn("dist_to_intersection", dist("lat", "lon", "actual_lat", "actual_lon")) \
    .withColumn("rank_dist", row_number().over(Window.partitionBy(["logID", "deviceID", "id", "routeName", "direction"]).orderBy("dist_to_intersection")))

trip_datas_crossing_intersections = zoned_trip_data_intersection.filter("rank_dist == 1") \
    .filter(zoned_trip_data_intersection.dist_to_intersection < dist_to_be_crossing_thresh).orderBy("time")

# %%
# save trip_datas_crossing_intersections to dict to make it work faster

from collections import defaultdict
log_id_device_id_to_trip_datas_crossing_intersections = defaultdict(list)

for row in trip_datas_crossing_intersections.collect():
    log_id_device_id_to_trip_datas_crossing_intersections[str(row["logID"]) + "_" + str(row["deviceID"])].append(row)

# %%
# save breadcrumbs with 'stop arrive', 'stop depart' to dict to later detect breadcrumbs between those events

log_id_device_id_to_trip_datas_arrive_depart = defaultdict(list)

for row in zoned_trip_data.filter("event IN ('stop arrive', 'stop depart')").collect():
    log_id_device_id_to_trip_datas_arrive_depart[row['logID'] + "_" + row['deviceID']].append(row)

# %%
# sequential stop arrive stop depart indexes saved in dict
log_id_device_id_to_stoparrive_stopdepart_indexes = defaultdict(list)

for key, val in log_id_device_id_to_trip_datas_arrive_depart.items():
    stop_arrive_depart_breadcrumbs = val
    cur_stop_arrive_stopdepart_indexes = []
    for ind, row in enumerate(stop_arrive_depart_breadcrumbs):
        if ind + 1 < len(stop_arrive_depart_breadcrumbs) and (row['event'] == "stop arrive") and (stop_arrive_depart_breadcrumbs[ind + 1]['event'] == "stop depart"):
            cur_stop_arrive_stopdepart_indexes.append({'arrive': row["breadcrumb_index"], 'depart': stop_arrive_depart_breadcrumbs[ind + 1]["breadcrumb_index"]})
    
    log_id_device_id_to_stoparrive_stopdepart_indexes[key] = cur_stop_arrive_stopdepart_indexes

# %% [markdown]
# ## Upcoming intersection detection

# %%
import json

def get_upcoming_intersection_factory(log_id_device_id_to_trip_datas_crossing_intersections_broadcasted):
    
    def get_upcoming_intersection(log_id, device_id, lat, lon, breadcrumb_index, dist_threshold):
        """
        log_id - log_id to identify trip in combination with device_id
        device_id - device_id identify trip in combination with log_id
        breadcrumb_index - breadcrumb_index attribute for given breadcrumb (generated at previous steps)
        log_id_device_id_to_trip_datas_crossing_intersections - dict where keys are strings [logID]_[deviceID]
        and values are lists of rows in tripdatas where crossing the intersection happened
        dist_threshold - max distance of bus to intersection so it is considered to be affected by that intersection

        returns: string representation of dict
        
        if upcoming_intersection is found (such that goes after breadcrumb within threshold distance),
        its info is given in intersection_loc_id, dist_to_upcoming_intersection fields
        otherwise reason not found explained in note_upcoming field
        
        intersection_loc_id - id of location of upcoming intersection if found
        dist_to_upcoming_intersection - distance in m to upcoming intersection
        note_upcoming - string explaining why an upcoming intersection is considered to be not found
        """
        # take all trip_datas_crossing_intersections for given trip
        cur_trip_datas_crossing_intersections = log_id_device_id_to_trip_datas_crossing_intersections_broadcasted.value.get(log_id + "_" + device_id)
        if cur_trip_datas_crossing_intersections:
            # leave only upcoming (with larger index than current) trip_datas_crossing_intersections with valid distace threshold
            cur_trip_datas_crossing_intersections_filtered = list(filter(lambda x: x["breadcrumb_index"] > breadcrumb_index, cur_trip_datas_crossing_intersections))
            if cur_trip_datas_crossing_intersections_filtered:
                # if there are several such intersections, take closest by time
                breadcrumb_crossing_intersection = min(cur_trip_datas_crossing_intersections_filtered, key=lambda x : x["breadcrumb_index"])
                dist_to_upcoming_intersection = dist_simple(breadcrumb_crossing_intersection["actual_lat"], breadcrumb_crossing_intersection["actual_lon"] ,lat ,lon)
                if dist_to_upcoming_intersection < dist_threshold:
                    return json.dumps({"intersection_loc_id": breadcrumb_crossing_intersection["id"], "dist_to_upcoming_intersection": dist_to_upcoming_intersection, "note_upcoming": None})
                else:
                    return json.dumps({"intersection_loc_id": None, "dist_to_upcoming_intersection": None, "note_upcoming": "distance to upcoming intersection: " + str(dist_to_upcoming_intersection) + " >= " + str(dist_threshold) + " \n potential upcoming id: " + str(breadcrumb_crossing_intersection["id"])})
            else:
                return json.dumps({"intersection_loc_id": None ,  "dist_to_upcoming_intersection": None, "note_upcoming": "no upcoming found"})
        return json.dumps({"intersection_loc_id": None ,  "dist_to_upcoming_intersection": None, "note_upcoming": "no crossing intersections on trip"})
    return udf(get_upcoming_intersection)

# %%
log_id_device_id_to_trip_datas_crossing_intersections_broadcasted = spark.sparkContext.broadcast(log_id_device_id_to_trip_datas_crossing_intersections)

# %%
get_upcoming_intersection_udf = get_upcoming_intersection_factory(log_id_device_id_to_trip_datas_crossing_intersections_broadcasted)

# %%
# max distance to upcoming intersection for it to be considered to possibly affect (cause delay) the bus
dist_threshold = 70

# %%
zoned_trip_data_intersection = zoned_trip_data_intersection \
    .withColumn('upcoming_intersection', get_upcoming_intersection_udf('logID', 'deviceID', 'lat', 'lon', 'breadcrumb_index', lit(dist_threshold)))

# %%
def upcoming_intersection_str_to_loc_id(upcoming_intersection):
    upcoming_intersection_val = json.loads(upcoming_intersection)
    return upcoming_intersection_val["intersection_loc_id"]

def upcoming_intersection_str_to_dist(upcoming_intersection):
    upcoming_intersection_val = json.loads(upcoming_intersection)
    return upcoming_intersection_val["dist_to_upcoming_intersection"]

def upcoming_intersection_str_to_note_upcoming(upcoming_intersection):
    upcoming_intersection_val = json.loads(upcoming_intersection)
    return upcoming_intersection_val["note_upcoming"]

upcoming_intersection_str_to_loc_id_udf = udf(upcoming_intersection_str_to_loc_id, StringType())
upcoming_intersection_str_to_dist_udf = udf(upcoming_intersection_str_to_dist, FloatType())
upcoming_intersection_str_to_note_upcoming_udf = udf(upcoming_intersection_str_to_note_upcoming, StringType())

# %%
zoned_trip_data_intersection = zoned_trip_data_intersection \
    .withColumn('upcoming_intersection_loc_id', upcoming_intersection_str_to_loc_id_udf("upcoming_intersection")) \
    .withColumn('dist_to_upcoming_intersection', upcoming_intersection_str_to_dist_udf("upcoming_intersection")) \
    .withColumn('upcoming_intersection_note', upcoming_intersection_str_to_note_upcoming_udf("upcoming_intersection"))

# %%
#t = zoned_trip_data_intersection.limit(500).toPandas()

# %%
#t.head()
# Out:
#            zone_id         lon        lat                    time routeName  \
# 0  89283082a3bffff -122.396702  37.790425 2020-11-08 05:00:46.529       14R
# 1  89283082a3bffff -122.396523  37.790543 2020-11-08 05:00:49.024       14R
# 2  89283082a3bffff -122.396583  37.790497 2020-11-08 05:00:47.783       14R
# 3  89283082a3bffff -122.396743  37.790390 2020-11-08 05:00:45.269       14R
# 4  89283082a3bffff -122.396047  37.791120 2020-11-08 05:01:38.751       14R
#
#   direction   tripID         logID    deviceID event  ...  \
# 0   inbound  9556430  20201107-t10  4010KM2034   GPS  ...
# 1   inbound  9556430  20201107-t10  4010KM2034   GPS  ...
# 2   inbound  9556430  20201107-t10  4010KM2034   GPS  ...
# 3   inbound  9556430  20201107-t10  4010KM2034   GPS  ...
# 4   inbound  9556430  20201107-t10  4010KM2034   GPS  ...
#
#                                      id                      name actual_lat  \
# 0  929957C2-546E-435C-A24D-EC5094C9BADF  Market/Front and Fremont    37.7917
# 1  929957C2-546E-435C-A24D-EC5094C9BADF  Market/Front and Fremont    37.7917
# 2  929957C2-546E-435C-A24D-EC5094C9BADF  Market/Front and Fremont    37.7917
# 3  929957C2-546E-435C-A24D-EC5094C9BADF  Market/Front and Fremont    37.7917
# 4  929957C2-546E-435C-A24D-EC5094C9BADF  Market/Front and Fremont    37.7917
#
#   actual_lon  dist_to_intersection  rank_dist  \
# 0   -122.398            181.976852          1
# 1   -122.398            182.698979          2
# 2   -122.398            182.757230          3
# 3   -122.398            182.790120          4
# 4   -122.398            183.358724          5
#
#                                upcoming_intersection  \
# 0  {"intersection_loc_id": null, "dist_to_upcomin...
# 1  {"intersection_loc_id": null, "dist_to_upcomin...
# 2  {"intersection_loc_id": null, "dist_to_upcomin...
# 3  {"intersection_loc_id": null, "dist_to_upcomin...
# 4  {"intersection_loc_id": null, "dist_to_upcomin...
#
#    upcoming_intersection_loc_id dist_to_upcoming_intersection  \
# 0                          None                           NaN
# 1                          None                           NaN
# 2                          None                           NaN
# 3                          None                           NaN
# 4                          None                           NaN
#
#                           upcoming_intersection_note
# 0  distance to upcoming intersection: 97.13435272...
# 1  distance to upcoming intersection: 77.11142587...
# 2  distance to upcoming intersection: 84.42870985...
# 3  distance to upcoming intersection: 102.4662843...
# 4  distance to upcoming intersection: 119.0634740...
#
# [5 rows x 22 columns]

# %%
def is_delayed_by_intersection_factory(log_id_device_id_to_stoparrive_stopdepart_indexes_broadcasted):
    
    def is_delayed_by_intersection(log_id, device_id, breadcrumb_index, upcoming_intersection_loc_id, mph, mph_threshold):
        """
        log_id - log_id to identify trip in combination with device_id
        device_id - device_id identify trip in combination with log_id
        breadcrumb_index - breadcrumb_index attribute for given breadcrumb (generated at previous steps)
        upcoming_intersection_loc_id - id of upcoming intersection if found else None
        mph - speed of vehicle at that point in mph
        mph_threshold - max speed in mph of bus so it is considered to be delayed (usually low number such as 3-5)
        
        returns: string representation of dict
        
        is_delayed_by_intersection - bool (True if all conditions to be considered delayed by intersection are satisfied)
        is_delayed_by_intersection_note - string explaining why the bus is considered not to be delayed (if is_delayed_by_intersection False)

        """
        
        def is_on_busstop(log_id, device_id, breadcrumb_index):
            # helper function to detect if breadcrumb is between stop arrive, stop depart events
            stoparrive_stopdeparts = log_id_device_id_to_stoparrive_stopdepart_indexes_broadcasted.value.get(log_id + "_" + device_id)
            for arrive_depart in stoparrive_stopdeparts:
                if (breadcrumb_index >= arrive_depart['arrive']) and (breadcrumb_index <= arrive_depart['depart']):
                    return True
            return False
        
        # if no upcoming intersection detected -> False 
        if upcoming_intersection_loc_id is None:
            return json.dumps({"is_delayed_by_intersection": False, "is_delayed_by_intersection_note": "upcoming intersection not found"})
        
        if mph > mph_threshold:
            return json.dumps({"is_delayed_by_intersection": False, "is_delayed_by_intersection_note": "mph > mph_threshold"})
        
        # if mph <= mph_threshold and it is between stop arrive, stop depart events -> False
        if is_on_busstop(log_id, device_id, breadcrumb_index):
            return json.dumps({"is_delayed_by_intersection": False, "is_delayed_by_intersection_note": "on bus stop"})
        
        return json.dumps({"is_delayed_by_intersection": True, "is_delayed_by_intersection_note": None})
    
    return udf(is_delayed_by_intersection)

# %%
log_id_device_id_to_stoparrive_stopdepart_indexes_broadcasted = spark.sparkContext.broadcast(log_id_device_id_to_stoparrive_stopdepart_indexes)

# %%
is_delayed_by_intersection_udf = is_delayed_by_intersection_factory(log_id_device_id_to_stoparrive_stopdepart_indexes_broadcasted)

# %%
mph_threshold = 3

# %%
zoned_trip_data_intersection = zoned_trip_data_intersection \
    .withColumn('is_delayed_by_intersection_str', is_delayed_by_intersection_udf('logID', 'deviceID', 'breadcrumb_index', 'upcoming_intersection_loc_id' , 'mph', lit(mph_threshold)))

# %%
def is_delayed_by_intersection_str_to_bool(is_delayed_by_intersection_str):
    is_delayed_by_intersection_val = json.loads(is_delayed_by_intersection_str)
    return is_delayed_by_intersection_val["is_delayed_by_intersection"]

def is_delayed_by_intersection_str_to_note(is_delayed_by_intersection_str):
    is_delayed_by_intersection_val = json.loads(is_delayed_by_intersection_str)
    return is_delayed_by_intersection_val["is_delayed_by_intersection_note"]

is_delayed_by_intersection_str_to_bool_udf = udf(is_delayed_by_intersection_str_to_bool, BooleanType())
is_delayed_by_intersection_str_to_note_udf = udf(is_delayed_by_intersection_str_to_note)

# %%
zoned_trip_data_intersection = zoned_trip_data_intersection \
    .withColumn('is_delayed_by_intersection', is_delayed_by_intersection_str_to_bool_udf("is_delayed_by_intersection_str")) \
    .withColumn('is_delayed_by_intersection_note', is_delayed_by_intersection_str_to_note_udf("is_delayed_by_intersection_str")) \
    .distinct()

# %%
#t = zoned_trip_data_intersection.limit(500).toPandas()

# %%
#t[["mph","is_delayed_by_intersection_note", "upcoming_intersection_note", "is_delayed_by_intersection"]].head()
# Out:
#          mph  is_delayed_by_intersection_note  \
# 0   0.000000                      on bus stop
# 1  15.075218  upcoming intersection not found
# 2   7.825304              mph > mph_threshold
# 3  10.011786  upcoming intersection not found
# 4  13.349048  upcoming intersection not found
#
#                           upcoming_intersection_note  \
# 0                                               None
# 1  distance to upcoming intersection: 512.9754838...
# 2                                               None
# 3  distance to upcoming intersection: 162.9699541...
# 4  distance to upcoming intersection: 380.1526322...
#
#    is_delayed_by_intersection
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
t[t["is_delayed_by_intersection"]].head()
# Out:
#             zone_id         lon        lat                    time routeName  \
# 16  89283082a37ffff -122.404000  37.789623 2020-11-10 00:30:26.865         8
# 30  8928309564fffff -122.402877  37.711993 2020-11-10 02:42:39.221         8
# 68  89283082b43ffff -122.408647  37.797952 2020-11-11 03:25:58.781         8
# 69  89283082b43ffff -122.408647  37.797952 2020-11-11 03:26:08.645         8
# 73  89283082a33ffff -122.401982  37.788595 2020-11-11 00:01:47.113        9R
#
#    direction   tripID         logID    deviceID event  ...  actual_lon  \
# 16   inbound  9547103   20201109-t1  4010KJ1053   GPS  ...    -122.404
# 30   inbound  9547135   20201109-t3  4010KJ1053   GPS  ...    -122.404
# 68  outbound  9546992   20201110-t1  4010KJ1133   GPS  ...    -122.409
# 69  outbound  9546992   20201110-t1  4010KJ1133   GPS  ...    -122.409
# 73   inbound  9560066  20201110-t11  4010KK1233   GPS  ...    -122.402
#
#     dist_to_intersection rank_dist  \
# 16            230.914808        54
# 30            132.462504        80
# 68             49.929018        18
# 69             49.929018        26
# 73            167.356148        28
#
#                                 upcoming_intersection  \
# 16  {"intersection_loc_id": "7E92EEC9-C68D-4329-93...
# 30  {"intersection_loc_id": "F49D7B83-2A9D-4603-9C...
# 68  {"intersection_loc_id": "669BE48F-8F99-41BC-AE...
# 69  {"intersection_loc_id": "669BE48F-8F99-41BC-AE...
# 73  {"intersection_loc_id": "EB6F5973-DD11-4ED7-96...
#
#             upcoming_intersection_loc_id  dist_to_upcoming_intersection  \
# 16  7E92EEC9-C68D-4329-936E-F68FF58BA019                      19.644497
# 30  F49D7B83-2A9D-4603-9C37-CDC12798D42B                      25.412533
# 68  669BE48F-8F99-41BC-AE17-24E5CE65CE02                      49.928928
# 69  669BE48F-8F99-41BC-AE17-24E5CE65CE02                      49.928928
# 73  EB6F5973-DD11-4ED7-9607-3755BF831C8C                      22.851618
#
#     upcoming_intersection_note  \
# 16                        None
# 30                        None
# 68                        None
# 69                        None
# 73                        None
#
#                        is_delayed_by_intersection_str  \
# 16  {"is_delayed_by_intersection": true, "is_delay...
# 30  {"is_delayed_by_intersection": true, "is_delay...
# 68  {"is_delayed_by_intersection": true, "is_delay...
# 69  {"is_delayed_by_intersection": true, "is_delay...
# 73  {"is_delayed_by_intersection": true, "is_delay...
#
#    is_delayed_by_intersection is_delayed_by_intersection_note
# 16                       True                            None
# 30                       True                            None
# 68                       True                            None
# 69                       True                            None
# 73                       True                            None
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Delayed time frames detection

# %%
tsp_on__routeName_direction_to_delayed_points = defaultdict(list)
tsp_off__routeName_direction_to_delayed_points = defaultdict(list)

for row in zoned_trip_data_intersection.filter(col("is_delayed_by_intersection") == True) \
    .select("upcoming_intersection_loc_id", "time", "is_delayed_by_intersection", "routeName", "direction", "deviceID", "logID", "tspMode"
           ).collect():
    
    res = {"upcoming_intersection_loc_id": row["upcoming_intersection_loc_id"], 
              "logID": row["logID"],
              "deviceID": row["deviceID"],
              "time": row["time"]}
    
    if row["tspMode"] == "alwaysOff":
        tsp_off__routeName_direction_to_delayed_points[row["routeName"] + "_" + row["direction"]].append(res)
    else:
        tsp_on__routeName_direction_to_delayed_points[row["routeName"] + "_" + row["direction"]].append(res)

pd.to_pickle(tsp_on__routeName_direction_to_delayed_points, "tsp_on__routeName_direction_to_delayed_points.pkl")
pd.to_pickle(tsp_off__routeName_direction_to_delayed_points, "tsp_off__routeName_direction_to_delayed_points.pkl")

# %%
tsp_on__routeName_direction_to_delayed_points['9R_inbound']
# Out:
# [{'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 30, 530000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 31, 771000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 33, 6000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 34, 246000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 35, 496000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 36, 732000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 37, 965000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 39, 200000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 40, 476000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 41, 710000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 51, 42, 946000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 1, 471000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 2, 707000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 3, 943000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 5, 220000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 6, 466000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 7, 706000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 8, 999000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 10, 243000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 11, 489000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 12, 726000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 13, 965000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 15, 203000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 16, 453000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 17, 694000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 18, 940000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 20, 182000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 21, 414000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 22, 646000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 23, 934000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 25, 167000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 26, 405000)},
#  {'upcoming_intersection_loc_id': '5FE6676A-5DE5-4874-B55C-B393C45E9D50',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 18, 55, 27, 640000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 41, 116000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 42, 355000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 43, 600000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 44, 833000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 46, 66000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 47, 299000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 48, 531000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 49, 765000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 50, 998000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 52, 238000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 53, 471000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 54, 704000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 55, 935000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 57, 166000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 58, 401000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 57, 59, 669000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 0, 911000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 2, 145000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 3, 395000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 4, 628000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 5, 866000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 7, 98000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 8, 331000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 18, 58, 9, 563000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 36, 93000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 37, 334000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 38, 582000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 39, 935000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 41, 175000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 42, 414000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 43, 653000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 44, 939000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 46, 177000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 47, 439000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 48, 701000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 49, 939000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 51, 173000)},
#  {'upcoming_intersection_loc_id': 'BA4531A5-1962-4316-B8D3-0066F8C28185',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 0, 52, 404000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 16, 948000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 18, 215000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 19, 452000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 20, 685000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 21, 921000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 23, 156000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 24, 389000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 25, 623000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 26, 855000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 28, 97000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 29, 348000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 30, 591000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 31, 838000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 33, 77000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 34, 325000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 35, 568000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 35, 789000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 36, 812000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 37, 26000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 38, 54000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 38, 270000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 39, 294000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 39, 531000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 40, 553000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 40, 768000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 41, 803000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 42, 7000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 43, 51000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 43, 241000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 44, 292000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 44, 499000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 45, 535000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 45, 736000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 46, 772000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 46, 968000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 48, 50000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 48, 204000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 49, 283000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 49, 444000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 50, 517000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 50, 676000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 51, 754000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 51, 911000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 52, 988000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 53, 142000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 54, 221000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 54, 386000)},
#  {'upcoming_intersection_loc_id': '4EFB2E1F-F7A3-4583-947F-0BCF9E311C0B',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 55, 453000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 55, 618000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 56, 851000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 58, 82000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 2, 59, 318000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 0, 549000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 1, 785000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 3, 15000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 4, 249000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 5, 486000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 6, 717000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 7, 953000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 9, 192000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 10, 432000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 11, 662000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 12, 894000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 14, 127000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 15, 359000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 16, 590000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 17, 823000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 19, 55000)},
#  {'upcoming_intersection_loc_id': 'CB70D248-E9C4-4DCE-A2A5-ADAC9AD71761',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 3, 20, 297000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 36, 38000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 36, 38000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 36, 38000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 36, 38000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 37, 412000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 37, 412000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 37, 412000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 37, 412000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 38, 689000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 38, 689000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 38, 689000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 38, 689000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 39, 949000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 39, 949000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 39, 949000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 39, 949000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 41, 206000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 41, 206000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 41, 206000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 41, 206000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 42, 490000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 42, 490000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 42, 490000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 42, 490000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 43, 744000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 43, 744000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 43, 744000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 43, 744000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 45, 16000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 45, 16000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 45, 16000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 45, 16000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 46, 261000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 46, 261000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 46, 261000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 46, 261000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 47, 515000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 47, 515000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 47, 515000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 47, 515000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 48, 809000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 48, 809000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 48, 809000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 48, 809000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 50, 69000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 50, 69000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 50, 69000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 50, 69000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 51, 308000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 51, 308000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 51, 308000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 51, 308000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 52, 548000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 52, 548000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 52, 548000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 52, 548000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 53, 888000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 53, 888000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 53, 888000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 53, 888000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 55, 142000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 55, 142000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 55, 142000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 55, 142000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 56, 392000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 56, 392000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 56, 392000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 11, 56, 392000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 11, 414000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 11, 414000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 12, 684000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 12, 684000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 13, 930000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 13, 930000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 15, 196000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 15, 196000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 16, 474000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 16, 474000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 17, 740000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 17, 740000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 19, 85000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 19, 85000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 20, 344000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 20, 344000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 21, 606000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 21, 606000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 22, 922000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 22, 922000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 24, 176000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 24, 176000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 25, 419000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 25, 419000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 26, 657000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 26, 657000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 27, 912000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 27, 912000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 29, 152000)},
#  {'upcoming_intersection_loc_id': '2D228FB1-F78D-45D4-957A-198B13935AB3',
#   'logID': '20201109-t3',
#   'deviceID': '4010KJ1095',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 29, 152000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 35, 761000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 35, 761000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 37, 58000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 37, 58000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 38, 358000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 38, 358000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 39, 610000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 39, 610000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 40, 868000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 40, 868000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 42, 128000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 42, 128000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 43, 377000)},
#  {'upcoming_intersection_loc_id': '6C9EC55A-5E74-401B-9FAF-40C2CBC1846F',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 12, 43, 377000)},
# ...
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 33, 859000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 33, 859000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 33, 859000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 35, 113000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 35, 113000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 35, 113000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 35, 113000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 36, 347000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 36, 347000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 36, 347000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 36, 347000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 37, 580000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 37, 580000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 37, 580000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 37, 580000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 38, 819000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 38, 819000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 38, 819000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 38, 819000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 40, 94000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 40, 94000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 40, 94000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 40, 94000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 41, 327000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 41, 327000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 41, 327000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 41, 327000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 42, 560000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 42, 560000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 42, 560000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 42, 560000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 43, 794000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 43, 794000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 43, 794000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 43, 794000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 45, 26000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 45, 26000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 45, 26000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 45, 26000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 46, 265000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 46, 265000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 46, 265000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 46, 265000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 47, 499000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 47, 499000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 47, 499000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 47, 499000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 48, 731000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 48, 731000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 48, 731000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 48, 731000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 49, 974000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 49, 974000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 49, 974000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 49, 974000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 51, 208000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 51, 208000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 51, 208000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 51, 208000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 52, 468000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 52, 468000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 52, 468000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 52, 468000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 53, 712000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 53, 712000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 53, 712000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 53, 712000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 54, 956000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 54, 956000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 54, 956000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 54, 956000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 56, 251000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 56, 251000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 56, 251000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 56, 251000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 57, 562000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 57, 562000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 57, 562000)},
#  {'upcoming_intersection_loc_id': 'C0DC0178-F9E3-44B3-B950-55A296C65EDD',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK2059',
#   'time': datetime.datetime(2020, 11, 9, 19, 32, 57, 562000)},
#  {'upcoming_intersection_loc_id': '69D8EFDC-C339-4699-8325-4A06DFFDB469',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 33, 23, 693000)},
#  {'upcoming_intersection_loc_id': '69D8EFDC-C339-4699-8325-4A06DFFDB469',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 33, 23, 693000)},
#  {'upcoming_intersection_loc_id': '69D8EFDC-C339-4699-8325-4A06DFFDB469',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 33, 23, 693000)},
#  {'upcoming_intersection_loc_id': '69D8EFDC-C339-4699-8325-4A06DFFDB469',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 33, 23, 693000)},
#  {'upcoming_intersection_loc_id': '69D8EFDC-C339-4699-8325-4A06DFFDB469',
#   'logID': '20201109-t1',
#   'deviceID': '4010KK1177',
#   'time': datetime.datetime(2020, 11, 9, 19, 33, 23, 693000)},
#  ...]

# %%
tsp_on__routeName_direction_to_delayed_frames = defaultdict(list)
tsp_off__routeName_direction_to_delayed_frames = defaultdict(list)


max_time_between_sequential = timedelta(seconds = 15)


def delay_points_dict__to_delayed_frames_dict(tsp_routeName_direction_to_delayed_points, max_time_between_sequential):
    tsp_routeName_direction_to_delayed_frames = defaultdict(list)
    for k, val in tsp_routeName_direction_to_delayed_points.items():
        cur_delayed_points = val
        cur_delayed_points.sort(key = lambda x: x['time'])
        cur_upcoming_intersection = cur_delayed_points[0]['upcoming_intersection_loc_id']
        cur_delay = timedelta(seconds = 0)

        for ind, p in enumerate(cur_delayed_points):
            if ind + 1 < len(cur_delayed_points):
                next_p = cur_delayed_points[ind + 1]
                if next_p['upcoming_intersection_loc_id'] == cur_upcoming_intersection:
                    if next_p['time'] - p['time'] < max_time_between_sequential:
                        cur_delay += next_p['time'] - p['time']
                    else:
                        res = {"upcoming_intersection_loc_id": cur_upcoming_intersection,
                                    "logID": p["logID"],
                                    "deviceID": p["deviceID"],
                                    "time_delay": cur_delay}
                        
                        tsp_routeName_direction_to_delayed_frames[k].append(res)
                        cur_delay = timedelta(seconds = 0)
                        
                else:
                    res = {"upcoming_intersection_loc_id": cur_upcoming_intersection,
                                "logID": p["logID"],
                                "deviceID": p["deviceID"],
                                "time_delay": cur_delay}
                    
                    tsp_routeName_direction_to_delayed_frames[k].append(res)
                        
                    cur_delay = timedelta(seconds = 0)
                    cur_upcoming_intersection = next_p['upcoming_intersection_loc_id']
    return tsp_routeName_direction_to_delayed_frames

# %%
tsp_on__routeName_direction_to_delayed_frames = delay_points_dict__to_delayed_frames_dict(tsp_on__routeName_direction_to_delayed_points,
                                                                                         max_time_between_sequential)

tsp_off__routeName_direction_to_delayed_frames = delay_points_dict__to_delayed_frames_dict(tsp_off__routeName_direction_to_delayed_points,
                                                                                         max_time_between_sequential)

# %%
tsp_off__routeName_direction_to_delayed_frames['45_inbound']
# Out:
# [{'upcoming_intersection_loc_id': 'AC91C7D0-3378-41CA-96E8-DF753DB1D11F',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=7, microseconds=434000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=52, microseconds=186000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=24, microseconds=773000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=23, microseconds=688000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=44, microseconds=738000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=44, microseconds=569000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=3, microseconds=824000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=25, microseconds=102000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=52, microseconds=9000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=40, microseconds=714000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(seconds=22, microseconds=528000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201107-t5',
#   'deviceID': '4010KW2050',
#   'time_delay': datetime.timedelta(microseconds=62000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=7, microseconds=465000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=63, microseconds=283000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=79, microseconds=656000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=62, microseconds=244000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=34, microseconds=799000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=53, microseconds=629000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(seconds=53, microseconds=381000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201109-t5',
#   'deviceID': '4010KO2016',
#   'time_delay': datetime.timedelta(microseconds=156000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(seconds=1, microseconds=241000)},
#  {'upcoming_intersection_loc_id': '58D26FCA-309D-448A-AE81-F80FB1353BB0',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(seconds=51, microseconds=233000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(seconds=29, microseconds=877000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(seconds=6, microseconds=202000)},
#  {'upcoming_intersection_loc_id': '79AE1395-B37A-4023-84AC-CDF6B41017C6',
#   'logID': '20201111-t1',
#   'deviceID': '4010KO2015',
#   'time_delay': datetime.timedelta(seconds=44, microseconds=946000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=51, microseconds=982000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=29, microseconds=654000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=29, microseconds=763000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=40, microseconds=922000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=41, microseconds=81000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=27, microseconds=837000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=22, microseconds=324000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=55, microseconds=841000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=17, microseconds=276000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=13, microseconds=672000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201112-t1',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(microseconds=160000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=58, microseconds=462000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=41, microseconds=68000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=37, microseconds=136000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=38, microseconds=487000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=3, microseconds=742000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=46, microseconds=23000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=55, microseconds=443000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201112-t3',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=52, microseconds=102000)},
#  {'upcoming_intersection_loc_id': '3329A9EE-9CA4-42C1-B6CF-96DD84966EB0',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=3, microseconds=738000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=63, microseconds=305000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=48, microseconds=522000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=16, microseconds=204000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=17, microseconds=432000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=63, microseconds=710000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=33, microseconds=479000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=4, microseconds=958000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201112-t5',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=65, microseconds=794000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201112-t7',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=43, microseconds=708000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201112-t7',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=55, microseconds=913000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201112-t7',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=37, microseconds=309000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201112-t7',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=58, microseconds=596000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201112-t7',
#   'deviceID': '4010KP2008',
#   'time_delay': datetime.timedelta(seconds=66, microseconds=865000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=3, microseconds=771000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=13, microseconds=696000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=61, microseconds=211000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=21, microseconds=352000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=41, microseconds=258000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=16, microseconds=205000)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=1, microseconds=240000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=29, microseconds=847000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=4, microseconds=976000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=63, microseconds=499000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t1',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(microseconds=666000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=15, microseconds=791000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=17, microseconds=439000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=41, microseconds=140000)},
#  {'upcoming_intersection_loc_id': '58D26FCA-309D-448A-AE81-F80FB1353BB0',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=8, microseconds=857000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=49, microseconds=868000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': '8C187246-8DF9-46E1-815C-7717AF42EEBD',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=124, microseconds=702000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=41, microseconds=165000)},
#  {'upcoming_intersection_loc_id': 'C8E92179-1012-4D38-98EE-8261347720F6',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=49, microseconds=863000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=58, microseconds=614000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=31, microseconds=115000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t3',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(microseconds=662000)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=55, microseconds=948000)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=70, microseconds=677000)},
#  {'upcoming_intersection_loc_id': '669BE48F-8F99-41BC-AE17-24E5CE65CE02',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=77, microseconds=188000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=3, microseconds=771000)},
#  {'upcoming_intersection_loc_id': '58D26FCA-309D-448A-AE81-F80FB1353BB0',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=6, microseconds=239000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=1, microseconds=259000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(microseconds=25000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=1, microseconds=239000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=79, microseconds=699000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t5',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': '04D6A65A-6B04-4C1F-9C22-34F442466717',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': 'BD18DBDC-15F6-444E-8891-F351E5711ECA',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=25, microseconds=83000)},
#  {'upcoming_intersection_loc_id': '21B3569F-1B62-47A0-848D-4989211C354A',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(0)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=53, microseconds=559000)},
#  {'upcoming_intersection_loc_id': '58D26FCA-309D-448A-AE81-F80FB1353BB0',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=9, microseconds=936000)},
#  {'upcoming_intersection_loc_id': '065F4FA4-11B5-426E-8601-58F6D5FA8BD2',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=44, microseconds=887000)},
#  {'upcoming_intersection_loc_id': 'DE683B43-4CCD-4AEB-A22F-C1C6D707B032',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=43, microseconds=561000)},
#  {'upcoming_intersection_loc_id': 'CFFB12C8-C245-432C-8BD1-1A0E4DB89847',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=6, microseconds=203000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=61, microseconds=156000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t7',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=24, microseconds=820000)},
#  {'upcoming_intersection_loc_id': 'D17E1ECC-7878-4939-9D77-894AF7DEA342',
#   'logID': '20201113-t9',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=1, microseconds=253000)},
#  {'upcoming_intersection_loc_id': 'DF7A09E5-0E90-4305-B479-7B11C2CE8196',
#   'logID': '20201113-t9',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=66, microseconds=45000)},
#  {'upcoming_intersection_loc_id': 'D9674047-9456-4D9E-B140-88EE484ED7F5',
#   'logID': '20201113-t9',
#   'deviceID': '4010KW2026',
#   'time_delay': datetime.timedelta(seconds=44, microseconds=926000)}]

# %%
pd.to_pickle(tsp_on__routeName_direction_to_delayed_frames, "tsp_on__routeName_direction_to_delayed_frames.pkl")

# %%
pd.to_pickle(tsp_off__routeName_direction_to_delayed_frames, "tsp_off__routeName_direction_to_delayed_frames.pkl")
