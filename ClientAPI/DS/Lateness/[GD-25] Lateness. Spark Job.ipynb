# %%
# %load_ext lab_black

import numpy as np
import pandas as pd
import pyspark
import scipy.stats

spark = pyspark.sql.SparkSession.builder.appName(
    "[GD-25] Lateness. Spark Job.ipynb"
).getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6caadb10df7d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>[GD-25] Lateness. Spark Job.ipynb</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !tree -h --sort=size /var/lib/gtt/2020_11_8_to_2020_11_14
# Out:
# /var/lib/gtt/2020_11_8_to_2020_11_14
# ├── [4.0K]  CMS
# │   ├── [2.0G]  opticomdevicelog.csv
# │   ├── [607K]  intersectionstatusreport.csv
# │   ├── [ 25K]  opticomdevicelog_data_dictonary.docx
# │   └── [ 15K]  intersectionstatusreport_data_dictionary.docx
# └── [4.0K]  CVP
#     ├── [5.4G]  tripdatas.csv
#     ├── [3.3M]  triplogs.csv
#     ├── [1.4M]  devices.csv
#     ├── [ 18K]  triplogs_data_dictionary.docx
#     ├── [ 15K]  devices_data_dictionary.docx
#     └── [ 15K]  tripdatas_data_dictionary.docx
#
# 2 directories, 10 files

# %%
# %%time
spark.sql(
    """
    create table if not exists tripdatas
        using csv options (header = true, inferSchema = true)
        location '/var/lib/gtt/2020_11_8_to_2020_11_14/CVP/tripdatas.csv';
    """
)
spark.table("tripdatas").limit(5).toPandas().sort_index(1).T
# Out:
# CPU times: user 36 ms, sys: 10.8 ms, total: 46.8 ms
# Wall time: 1min 12s
#                                                             0  \
# __v                                                         0
# _id                            {oid=5faa4124348d72d817d58d65}
# date_ran                                           2020-11-08
# deviceid                                           4010KO2063
# dir                                                     170.3
# distance                                                  NaN
# dwelltime                                                 NaN
# emitterid                                                 NaN
# event                                                     GPS
# headway                                                   NaN
# loc         {coordinates=[-122.450408333333, 37.7678033333...
# logid                                             20201108-t4
# mph                                                 29.575046
# routename                                                NBUS
# stopindex                                                 NaN
# stopname                                                 None
# time                                  2020-11-08 19:05:12.865
# tracktime                                                 NaN
# traveltime                                                NaN
# unloc                        {coordinates=[0, 0], type=Point}
#
#                                                             1  \
# __v                                                         0
# _id                            {oid=5fa7624a6e3fbb64170cb171}
# date_ran                                           2020-11-08
# deviceid                                           4010KM2146
# dir                                                       6.7
# distance                                                  NaN
# dwelltime                                                 NaN
# emitterid                                                 NaN
# event                                                     GPS
# headway                                                   NaN
# loc         {coordinates=[-122.467738333333, 37.706645], t...
# logid                                             20201107-t5
# mph                                                  7.825304
# routename                                                 14R
# stopindex                                                 NaN
# stopname                                                 None
# time                                  2020-11-08 00:48:32.501
# tracktime                                                 NaN
# traveltime                                                NaN
# unloc                        {coordinates=[0, 0], type=Point}
#
#                                                             2  \
# __v                                                         0
# _id                            {oid=5fae1f0a63570cb8178eb0f6}
# date_ran                                           2020-11-08
# deviceid                                           4010KL2013
# dir                                                     196.5
# distance                                                  NaN
# dwelltime                                                 NaN
# emitterid                                                 NaN
# event                                                     GPS
# headway                                                   NaN
# loc         {coordinates=[-122.434473333333, 37.732675], t...
# logid                                             20201107-t5
# mph                                                  0.230156
# routename                                                JBUS
# stopindex                                                 NaN
# stopname                                                 None
# time                                  2020-11-08 02:15:06.037
# tracktime                                                 NaN
# traveltime                                                NaN
# unloc                        {coordinates=[0, 0], type=Point}
#
#                                                             3  \
# __v                                                         0
# _id                            {oid=5fa790ec348d72d8179491c6}
# date_ran                                           2020-11-08
# deviceid                                           4010KM2122
# dir                                                     350.0
# distance                                                  NaN
# dwelltime                                                 NaN
# emitterid                                                 NaN
# event                                                     GPS
# headway                                                   NaN
# loc         {coordinates=[-122.44625, 37.7747583333333], t...
# logid                                            20201107-t14
# mph                                                  6.789602
# routename                                                  43
# stopindex                                                 NaN
# stopname                                                 None
# time                                  2020-11-08 02:41:47.244
# tracktime                                                 NaN
# traveltime                                                NaN
# unloc                        {coordinates=[0, 0], type=Point}
#
#                                                             4
# __v                                                         0
# _id                            {oid=5faa138863570cb8172615c3}
# date_ran                                           2020-11-08
# deviceid                                           4010KO2042
# dir                                                      28.4
# distance                                                  NaN
# dwelltime                                                 NaN
# emitterid                                                 NaN
# event                                                     GPS
# headway                                                   NaN
# loc         {coordinates=[-122.403935, 37.7873433333333], ...
# logid                                            20201107-t11
# mph                                                       0.0
# routename                                                NBUS
# stopindex                                                 NaN
# stopname                                                 None
# time                                  2020-11-08 02:05:45.780
# tracktime                                                 NaN
# traveltime                                                NaN
# unloc                        {coordinates=[0, 0], type=Point}

# %%
# %%time
spark.sql(
    """
    create table if not exists triplogs
        using csv options (header = true, inferSchema = true)
        location '/var/lib/gtt/2020_11_8_to_2020_11_14/CVP/triplogs.csv';
    """
)
spark.table("triplogs").limit(5).toPandas().sort_index(1).T
# Out:
# CPU times: user 37.1 ms, sys: 0 ns, total: 37.1 ms
# Wall time: 899 ms
#                                                0  \
# __v                                            0
# _id               {oid=5fb4d3f6fee809e415549371}
# countearly                                     0
# countlate                                      1
# countontime                                   39
# countstopshit                                 40
# counttsprequests                               0
# date_ran                              2020-11-09
# deviceid                              4010KK1211
# direction                               outbound
# duration                                4247.355
# earlylimit                                     1
# endreason                                   None
# endstatus                              completed
# endtime                  2020-11-09 17:13:12.953
# headsign                      Bayshore Boulevard
# headway                                       10
# latelimit                                      4
# logid                                20201109-t4
# routename                                      9
# routepriority                                  0
# starttime                2020-11-09 16:02:25.598
# stops                                         41
# syncedtocms                                False
# totaldwell                                   552
# totaltravel                                 2430
# tripid                                   9557462
# triptype                                schedule
# tspmode                                alwaysOff
# tzoffset                                    -800
# uploaddate               2020-11-18 07:57:42.946
# utcoffset                                   -480
# valid                                       True
# vehiclename                               NF8814
# verasmapp                                  1.8.1
# verasmserver                               1.8.1
#
#                                                1  \
# __v                                            0
# _id               {oid=5fb3380ffc9b903c16c4c186}
# countearly                                    50
# countlate                                      0
# countontime                                   41
# countstopshit                                 91
# counttsprequests                               0
# date_ran                              2020-11-09
# deviceid                              4010KK1199
# direction                                inbound
# duration                                4071.034
# earlylimit                                     1
# endreason                                   None
# endstatus                              completed
# endtime                  2020-11-09 22:49:50.589
# headsign                        Bayview District
# headway                                       10
# latelimit                                      4
# logid                                20201109-t6
# routename                                     54
# routepriority                                  0
# starttime                2020-11-09 21:41:59.555
# stops                                         92
# syncedtocms                                False
# totaldwell                                  1322
# totaltravel                                 2662
# tripid                                   9478132
# triptype                                schedule
# tspmode                                alwaysOff
# tzoffset                                    -800
# uploaddate               2020-11-17 02:40:15.622
# utcoffset                                   -480
# valid                                       True
# vehiclename                               NF8808
# verasmapp                                  1.8.1
# verasmserver                               1.8.1
#
#                                                2  \
# __v                                            0
# _id               {oid=5fabfaaed08f5774176ba697}
# countearly                                     1
# countlate                                      0
# countontime                                    1
# countstopshit                                  2
# counttsprequests                               0
# date_ran                              2020-11-09
# deviceid                              4010KO2020
# direction                               outbound
# duration                                 195.493
# earlylimit                                     1
# endreason                           new block ID
# endstatus                                aborted
# endtime                  2020-11-09 21:39:33.660
# headsign                                  SF Zoo
# headway                                       10
# latelimit                                      4
# logid                                20201109-t5
# routename                                   LBUS
# routepriority                                  0
# starttime                2020-11-09 21:36:18.167
# stops                                         37
# syncedtocms                                False
# totaldwell                                   174
# totaltravel                                   11
# tripid                                   9699545
# triptype                                schedule
# tspmode                                alwaysOff
# tzoffset                                    -800
# uploaddate               2020-11-11 14:52:30.235
# utcoffset                                   -480
# valid                                       True
# vehiclename                               NF8761
# verasmapp                                  1.8.1
# verasmserver                               1.8.1
#
#                                                3  \
# __v                                            0
# _id               {oid=5fa9f25780ad8ba417a8a80d}
# countearly                                    34
# countlate                                      0
# countontime                                   18
# countstopshit                                 52
# counttsprequests                              17
# date_ran                              2020-11-09
# deviceid                              4010KJ1133
# direction                               outbound
# duration                                4245.127
# earlylimit                                     1
# endreason                                   None
# endstatus                              completed
# endtime                  2020-11-09 19:19:10.958
# headsign                            City College
# headway                                       10
# latelimit                                      4
# logid                                20201109-t2
# routename                                      8
# routepriority                                  0
# starttime                2020-11-09 18:08:25.831
# stops                                         54
# syncedtocms                                False
# totaldwell                                  1016
# totaltravel                                 3180
# tripid                                   9546907
# triptype                                schedule
# tspmode                                 alwaysOn
# tzoffset                                    -800
# uploaddate               2020-11-10 01:52:23.539
# utcoffset                                   -480
# valid                                       True
# vehiclename                               NF6585
# verasmapp                                  1.8.1
# verasmserver                               1.8.1
#
#                                                4
# __v                                            0
# _id               {oid=5fad7017348d72d81723ed38}
# countearly                                    34
# countlate                                      1
# countontime                                   27
# countstopshit                                 62
# counttsprequests                               0
# date_ran                              2020-11-09
# deviceid                              4010KA0950
# direction                               outbound
# duration                                3933.813
# earlylimit                                     1
# endreason                                   None
# endstatus                              completed
# endtime                  2020-11-09 18:20:25.396
# headsign                         Munich + Geneva
# headway                                       10
# latelimit                                      4
# logid                                20201109-t2
# routename                                     43
# routepriority                                  0
# starttime                2020-11-09 17:14:51.583
# stops                                         68
# syncedtocms                                False
# totaldwell                                   566
# totaltravel                                 3330
# tripid                                   9548191
# triptype                                schedule
# tspmode                                alwaysOff
# tzoffset                                    -800
# uploaddate               2020-11-12 17:25:43.752
# utcoffset                                   -480
# valid                                       True
# vehiclename                               NF8913
# verasmapp                                  1.8.1
# verasmserver                               1.8.1

# %%
# %%time
(
    spark.sql(
        """
        select event, count(1) as count
        from tripdatas
        group by event;
        """
    )
    .toPandas()
    .sort_values("event")
    .style.bar()
)
# Out:
# CPU times: user 256 ms, sys: 59.4 ms, total: 315 ms
# Wall time: 1min 6s
# <style  type="text/css" >
# #T_ea88f_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_ea88f_row1_col1,#T_ea88f_row6_col1,#T_ea88f_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_ea88f_row2_col1,#T_ea88f_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }#T_ea88f_row4_col1,#T_ea88f_row5_col1,#T_ea88f_row10_col1,#T_ea88f_row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_ea88f_row8_col1,#T_ea88f_row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#         }#T_ea88f_row11_col1,#T_ea88f_row12_col1,#T_ea88f_row15_col1,#T_ea88f_row16_col1,#T_ea88f_row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_ea88f_row14_col1{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_ea88f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >event</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea88f_level0_row0" class="row_heading level0 row0" >14</th>
#                         <td id="T_ea88f_row0_col0" class="data row0 col0" >GPS</td>
#                         <td id="T_ea88f_row0_col1" class="data row0 col1" >22809702</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row1" class="row_heading level0 row1" >11</th>
#                         <td id="T_ea88f_row1_col0" class="data row1 col0" >TSP disable</td>
#                         <td id="T_ea88f_row1_col1" class="data row1 col1" >165591</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ea88f_row2_col0" class="data row2 col0" >TSP enable</td>
#                         <td id="T_ea88f_row2_col1" class="data row2 col1" >82575</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row3" class="row_heading level0 row3" >10</th>
#                         <td id="T_ea88f_row3_col0" class="data row3 col0" >TSP probe</td>
#                         <td id="T_ea88f_row3_col1" class="data row3 col1" >89332</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row4" class="row_heading level0 row4" >3</th>
#                         <td id="T_ea88f_row4_col0" class="data row4 col0" >TSP request</td>
#                         <td id="T_ea88f_row4_col1" class="data row4 col1" >27401</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_ea88f_row5_col0" class="data row5 col0" >TSP unrequest</td>
#                         <td id="T_ea88f_row5_col1" class="data row5 col1" >27424</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row6" class="row_heading level0 row6" >12</th>
#                         <td id="T_ea88f_row6_col0" class="data row6 col0" >front door close</td>
#                         <td id="T_ea88f_row6_col1" class="data row6 col1" >160457</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row7" class="row_heading level0 row7" >13</th>
#                         <td id="T_ea88f_row7_col0" class="data row7 col0" >front door open</td>
#                         <td id="T_ea88f_row7_col1" class="data row7 col1" >160830</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row8" class="row_heading level0 row8" >4</th>
#                         <td id="T_ea88f_row8_col0" class="data row8 col0" >stop arrive</td>
#                         <td id="T_ea88f_row8_col1" class="data row8 col1" >388874</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row9" class="row_heading level0 row9" >1</th>
#                         <td id="T_ea88f_row9_col0" class="data row9 col0" >stop depart</td>
#                         <td id="T_ea88f_row9_col1" class="data row9 col1" >380000</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row10" class="row_heading level0 row10" >8</th>
#                         <td id="T_ea88f_row10_col0" class="data row10 col0" >stop jump</td>
#                         <td id="T_ea88f_row10_col1" class="data row10 col1" >14796</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row11" class="row_heading level0 row11" >6</th>
#                         <td id="T_ea88f_row11_col0" class="data row11 col0" >trip abort</td>
#                         <td id="T_ea88f_row11_col1" class="data row11 col1" >2037</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row12" class="row_heading level0 row12" >0</th>
#                         <td id="T_ea88f_row12_col0" class="data row12 col0" >trip end</td>
#                         <td id="T_ea88f_row12_col1" class="data row12 col1" >9522</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row13" class="row_heading level0 row13" >17</th>
#                         <td id="T_ea88f_row13_col0" class="data row13 col0" >trip new</td>
#                         <td id="T_ea88f_row13_col1" class="data row13 col1" >11791</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row14" class="row_heading level0 row14" >7</th>
#                         <td id="T_ea88f_row14_col0" class="data row14 col0" >trip not started</td>
#                         <td id="T_ea88f_row14_col1" class="data row14 col1" >218</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row15" class="row_heading level0 row15" >16</th>
#                         <td id="T_ea88f_row15_col0" class="data row15 col0" >trip pending</td>
#                         <td id="T_ea88f_row15_col1" class="data row15 col1" >11353</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row16" class="row_heading level0 row16" >15</th>
#                         <td id="T_ea88f_row16_col0" class="data row16 col0" >trip resume</td>
#                         <td id="T_ea88f_row16_col1" class="data row16 col1" >1946</td>
#             </tr>
#             <tr>
#                         <th id="T_ea88f_level0_row17" class="row_heading level0 row17" >5</th>
#                         <td id="T_ea88f_row17_col0" class="data row17 col0" >trip start</td>
#                         <td id="T_ea88f_row17_col1" class="data row17 col1" >11271</td>
#             </tr>
#     </tbody></table>

# %%
# %%time
spark.sql(
    """
    cache table gd_tripdatas as (
        with gd_tripdatas as (
            select deviceid,
                   logid,
                   sum(if(event = 'stop depart', 1, 0))
                       over (partition by (deviceid, logid) order by `time`)
                       as gd_segment,
                   `time`,
                   event,
                   routename,
                   stopname,
                   tracktime
            from tripdatas
            where event in ('TSP request', 'stop arrive', 'stop depart')
        )
        select gd_tripdatas.*, triplogs.direction as gd_direction
        from gd_tripdatas
                 left join triplogs using (deviceid, logid)
    );
    """
)
spark.table("gd_tripdatas").show(5)
# Out:
# +----------+-----------+----------+--------------------+-----------+---------+--------------------+---------+------------+
# |  deviceid|      logid|gd_segment|                time|      event|routename|            stopname|tracktime|gd_direction|
# +----------+-----------+----------+--------------------+-----------+---------+--------------------+---------+------------+
# |4010JZ0888|20201110-t2|         0|2020-11-10 23:28:...|stop arrive|       22|Tennessee St & 18...|        0|     inbound|
# |4010JZ0888|20201110-t2|         1|2020-11-10 23:28:...|stop depart|       22|Tennessee St & 18...|        0|     inbound|
# |4010JZ0888|20201110-t2|         1|2020-11-10 23:29:...|stop arrive|       22|18th St & Pennsyl...|        0|     inbound|
# |4010JZ0888|20201110-t2|         2|2020-11-10 23:29:...|stop depart|       22|18th St & Pennsyl...|        0|     inbound|
# |4010JZ0888|20201110-t2|         2|2020-11-10 23:30:...|stop arrive|       22|  18th St & Texas St|        0|     inbound|
# +----------+-----------+----------+--------------------+-----------+---------+--------------------+---------+------------+
# only showing top 5 rows
#
# CPU times: user 14.7 ms, sys: 4.85 ms, total: 19.5 ms
# Wall time: 1min 28s

# %%
# %%time
spark.sql(
    """
    cache table gd_lateness as (
        select first(routename)                                                   as Route,
               first(gd_direction)                                                as Direction,
               first(if(event = 'stop depart', stopname, null), true)             as StopStart,
               to_timestamp(first(if(event = 'stop depart', `time`, null), true)) as StopStartTime,
               first(if(event = 'stop arrive', stopname, null), true)             as StopEnd,
               to_timestamp(first(if(event = 'stop arrive', `time`, null), true)) as StopEndTime,
               null                                                               as NumIntersections,
               1                                                                  as VehiclePassThrough,
               sum(if(event = 'TSP request', 1, 0))                               as NumRequests,
               (first(if(event = 'stop arrive', tracktime, null), true) -
                first(if(event = 'stop depart', tracktime, null), true))          as LatenessReduction
        from gd_tripdatas
        group by deviceid, logid, gd_segment
        having sum(if(event = 'stop arrive', 1, 0)) > 0
           and sum(if(event = 'stop depart', 1, 0)) > 0
        order by Route, Direction, StopStartTime
    );
    """
)
spark.table("gd_lateness").show(5)
# Out:
# +-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+------------------+-----------+-----------------+
# |Route|Direction|           StopStart|       StopStartTime|             StopEnd|         StopEndTime|NumIntersections|VehiclePassThrough|NumRequests|LatenessReduction|
# +-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+------------------+-----------+-----------------+
# |    1|  inbound|33rd Ave & Clemen...|2020-11-08 01:00:...|32nd Ave & Clemen...|2020-11-08 01:01:...|            null|                 1|          0|                0|
# |    1|  inbound|32nd Ave & Clemen...|2020-11-08 01:01:...|32nd Ave & Califo...|2020-11-08 01:02:...|            null|                 1|          0|               -1|
# |    1|  inbound|32nd Ave & Califo...|2020-11-08 01:02:...|California St & 3...|2020-11-08 01:02:...|            null|                 1|          0|                1|
# |    1|  inbound|California St & 3...|2020-11-08 01:02:...|California St & 2...|2020-11-08 01:02:...|            null|                 1|          0|                0|
# |    1|  inbound|California St & 2...|2020-11-08 01:03:...|California St & 2...|2020-11-08 01:03:...|            null|                 1|          0|                0|
# +-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+------------------+-----------+-----------------+
# only showing top 5 rows
#
# CPU times: user 6.89 ms, sys: 0 ns, total: 6.89 ms
# Wall time: 23.2 s
