# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import pymc3 as pm
import arviz as az
from scipy import stats
pd.set_option('display.max_columns', 500)
import warnings
from scipy.stats import spearmanr
import sys
warnings.filterwarnings("ignore")

import logging
logger = logging.getLogger('pymc3')
logger.setLevel(logging.CRITICAL)
# %matplotlib inline

# %%
sys.path.append("/Users/ailin/Documents/grid-dynamics/DS/data_cleaning/")

# %%
from data_preparation_faster import prepare_triplogs, prepare_tripdatas, get_clean_triplogs, get_clean_tripdatas, get_and_clean_tripdatas_triplogs_merge

# %% [markdown]
# # Data preparation

# %%
# %%time
from collections import defaultdict
filtration_dict=defaultdict(lambda: True)
# no need to drop tsp mode
filtration_dict["tspmode_not_normal_test"] = False

triplogs = pd.read_csv('../../../trips/2020_11_8_to_2020_11_14/CVP/triplogs.csv')
tripdatas = pd.read_csv('../../../trips/2020_11_8_to_2020_11_14/CVP/tripdatas.csv')

triplogs = prepare_triplogs(triplogs)
tripdatas = prepare_tripdatas(tripdatas)

# takes about 10 minutes to run

tripdatas = get_clean_tripdatas(tripdatas) # cleaning tripdatas first is important
tripdatas_df_good = tripdatas[tripdatas["is_good_for_study"]] # remove messy tripdatas now so it doesnt affect triplogs cleaning
triplogs = get_clean_triplogs(triplogs, tripdatas_df_good, filtration_dict)
triplogs_clean = triplogs[triplogs["is_good_for_study"]]

# triplogs_clean = add_columns_to_prepared_triplogs(triplogs_clean, tripdatas_df_good)
# Out:
# drop invalid
# drop starttime >= endtime
# drop endstatus not completed
# drop negative duration
# drop <=70% stops hit
# drop <=70% breadcrumbs
# drop duplicated rows
# drop tspon no tsp requests
# drop 3 stds anomalies
# CPU times: user 2min 56s, sys: 2min 21s, total: 5min 17s
# Wall time: 6min 50s

# %%
# drop all events except arrive/depart/request
tripdatas_df_good = tripdatas_df_good[tripdatas_df_good.event.isin(['stop depart', 'TSP request','stop arrive', 'routename'])]

# %%
# merge tripdatas with triplogs
# logdatas = tripdatas_df_good.merge(triplogs[['uid', 'direction']], on='uid', how='inner')
logdatas = get_and_clean_tripdatas_triplogs_merge(tripdatas_df_good, triplogs_clean[['uid', 'direction', 'routename']])
logdatas.rename({'routename_x': 'routename'}, axis=1, inplace=True)

# %%
logdatas.head()
# Out:
#    __v                             _id    deviceid    dir  distance  \
# 0    0  {oid=5fa7891e815102901719b9b0}  4010KO2052  177.2       NaN
# 1    0  {oid=5fa7891e815102901719b91d}  4010KO2052  176.6      11.0
# 2    0  {oid=5fa7891e815102901719b96a}  4010KO2052  167.9      27.0
# 3    0  {oid=5fa7891e815102901719b743}  4010KO2052  178.5     234.0
# 4    0  {oid=5fa7891e815102901719b693}  4010KO2052  179.2     255.0
#
#    dwelltime  emitterid        event  headway  \
# 0        NaN        NaN  TSP request      0.0
# 1        0.0        NaN  stop arrive      NaN
# 2       21.0        NaN  stop depart      NaN
# 3        1.0        NaN  stop depart      NaN
# 4        0.0        NaN  stop depart      NaN
#
#                                                  loc        logid        mph  \
# 0  {coordinates=[-122.476716666667, 37.7567366666...  20201107-t5  14.154594
# 1  {coordinates=[-122.476136666667, 37.74829], ty...  20201107-t5  20.483884
# 2  {coordinates=[-122.476523333333, 37.7539366666...  20201107-t5   7.825304
# 3  {coordinates=[-122.475416666667, 37.72092], ty...  20201107-t5  24.281458
# 4  {coordinates=[-122.471293333333, 37.7106216666...  20201107-t5  34.983712
#
#   routename  stopindex                              stopname  \
# 0        28        NaN                                   NaN
# 1        28       13.0               19th Ave & Quintara St:
# 2        28       11.0                19th Ave & Noriega St:
# 3        28       20.0               19th Ave & Holloway Ave
# 4        28       23.0  Junipero Serra Blvd / S.F. Golf Club
#
#                      time  tracktime  traveltime  \
# 0 2020-11-08 01:17:58.364        0.0         NaN
# 1 2020-11-08 01:20:39.701       -6.0        39.0
# 2 2020-11-08 01:19:14.292       -8.0         0.0
# 3 2020-11-08 01:29:47.754       -3.0         0.0
# 4 2020-11-08 01:33:09.144       -5.0         0.0
#
#                           unloc    date_ran                     uid  \
# 0  {coordinates=[], type=Point}  2020-11-08  4010KO2052_20201107-t5
# 1  {coordinates=[], type=Point}  2020-11-08  4010KO2052_20201107-t5
# 2  {coordinates=[], type=Point}  2020-11-08  4010KO2052_20201107-t5
# 3  {coordinates=[], type=Point}  2020-11-08  4010KO2052_20201107-t5
# 4  {coordinates=[], type=Point}  2020-11-08  4010KO2052_20201107-t5
#
#    is_good_for_study direction routename_y routename_direction
# 0               True  outbound          28         28_outbound
# 1               True  outbound          28         28_outbound
# 2               True  outbound          28         28_outbound
# 3               True  outbound          28         28_outbound
# 4               True  outbound          28         28_outbound

# %%
# we need to group by routename and direction, let's do it now
logdatas['routename_direction'] = logdatas['routename'] +'_'+ logdatas['direction']

# %%
from collections import defaultdict

def get_uid_to_curbreadcrumbs(tripdatas_df_good):
    """ make a {"routename_direction": df_tripdatas} """
    uid_to_curbreadcrumbs = {}
    tripdatas_df_good = tripdatas_df_good[tripdatas_df_good["event"].isin(['stop depart', 'TSP request','stop arrive'])].sort_values("time")
    for routename_direction in tripdatas_df_good.routename_direction.unique():
        # df_tripdatas for speciphic routename_direction
        t_df = tripdatas_df_good[tripdatas_df_good.routename_direction == routename_direction]
        if sum(t_df.event == 'TSP request') > 0:
            # start df with departing from the first bus stop
            while t_df.event.iloc[0] != 'stop depart':
                t_df = t_df.iloc[1:]
            if len(t_df.index) >= 2:
                uid_to_curbreadcrumbs[routename_direction] = t_df

    return uid_to_curbreadcrumbs

# %%
uid_to_curbreadcrumbs = get_uid_to_curbreadcrumbs(logdatas)

# %%
# check that it worked
uid_to_curbreadcrumbs['9_outbound'].head(2)
# Out:
#         __v                             _id    deviceid     dir  distance  \
# 379392    0  {oid=5faa3d9b80ad8ba417b63117}  4010KK2096  224.06     281.0
# 379428    0  {oid=5faa3d9b80ad8ba417b63063}  4010KK2096  241.66      63.0
#
#         dwelltime  emitterid        event  headway  \
# 379392        0.0        NaN  stop depart      NaN
# 379428        0.0        NaN  stop arrive      NaN
#
#                                                       loc         logid  \
# 379392  {coordinates=[-122.396468333333, 37.7935733333...  20201107-t19
# 379428  {coordinates=[-122.401366666667, 37.7893216666...  20201107-t19
#
#               mph routename  stopindex              stopname  \
# 379392  14.534351         9        2.0  Market St & Drumm St
# 379428  13.935946         9        4.0    Market St & 2nd St
#
#                           time  tracktime  traveltime  \
# 379392 2020-11-08 00:24:56.453        0.0         0.0
# 379428 2020-11-08 00:28:39.386        1.0       223.0
#
#                                unloc    date_ran                      uid  \
# 379392  {coordinates=[], type=Point}  2020-11-08  4010KK2096_20201107-t19
# 379428  {coordinates=[], type=Point}  2020-11-08  4010KK2096_20201107-t19
#
#         is_good_for_study direction routename_y routename_direction
# 379392               True  outbound           9          9_outbound
# 379428               True  outbound           9          9_outbound

# %%
# collect a table with segments durations
route_direction_start_depart_duration_tsp = [] # future df
for route_direction in uid_to_curbreadcrumbs:
    tsp = False
    depart_time = 0
    for idx, row in uid_to_curbreadcrumbs[route_direction].iterrows():
        event = row['event']
        if event == 'stop depart':
            depart_time = row['time']
            # starting bus stop
            start = row['stopname']
        elif event == 'stop arrive':
            route_direction_start_depart_duration_tsp.append( 
                [row.routename, row.direction, start, row.stopname, (row.time - depart_time).total_seconds(), tsp, depart_time, row.time]
            )
            tsp = False
        elif event == 'TSP request':
            tsp = True

# %%
route_direction_start_depart_duration_tsp[:2]
# Out:
# [['1',
#   'outbound',
#   'Sacramento St & Davis St',
#   'Sacramento St & Battery St',
#   92.992,
#   False,
#   Timestamp('2020-11-08 00:01:03.823000'),
#   Timestamp('2020-11-08 00:02:36.815000')],
#  ['1',
#   'outbound',
#   'Sacramento St & Battery St',
#   'Sacramento St & Sansome St',
#   61.722,
#   False,
#   Timestamp('2020-11-08 00:02:37.838000'),
#   Timestamp('2020-11-08 00:03:39.560000')]]

# %%
# form a df
segments_df = pd.DataFrame.from_records(route_direction_start_depart_duration_tsp)
segments_df.columns = ['routename', 'direction', 'start', 'end', 'duration', 'tspmode', 'starttime', 'endtime']
segments_df['starthour'] = segments_df.starttime.dt.hour

# %%
segments_df.head()
# Out:
#   routename direction                          start  \
# 0         1  outbound       Sacramento St & Davis St
# 1         1  outbound     Sacramento St & Battery St
# 2         1  outbound     Sacramento St & Sansome St
# 3         1  outbound  Sacramento St & Montgomery St
# 4         1  outbound      Sacramento St & Kearny St
#
#                              end  duration  tspmode               starttime  \
# 0     Sacramento St & Battery St    92.992    False 2020-11-08 00:01:03.823
# 1     Sacramento St & Sansome St    61.722    False 2020-11-08 00:02:37.838
# 2  Sacramento St & Montgomery St    17.147    False 2020-11-08 00:03:40.583
# 3      Sacramento St & Kearny St    61.788    False 2020-11-08 00:03:58.753
# 4      Sacramento St & Grant Ave    49.085    False 2020-11-08 00:05:01.570
#
#                   endtime  starthour
# 0 2020-11-08 00:02:36.815          0
# 1 2020-11-08 00:03:39.560          0
# 2 2020-11-08 00:03:57.730          0
# 3 2020-11-08 00:05:00.541          0
# 4 2020-11-08 00:05:50.655          0

# %%
sum(segments_df.duration < 0) # no troubles???
# Out:
# 0

# %% [markdown]
# # Hypotheses testing

# %%
# mann-whitney u-test
def mannwhitney(triplogs_on, triplogs_off):
    rejected = []
    total = 0
    for idx in triplogs_on.index:
        if idx in triplogs_off.index:
            total += 1
            pval = stats.mannwhitneyu(triplogs_on[idx], triplogs_off[idx], alternative='less').pvalue
            if pval < 0.05:
#                 print(idx, f'route is significally faster with pval {pval:.2f}')
                rejected.append(
                    (pval, idx)
                )
    print(len(rejected), 'of', total, 'rejected', len(rejected)/total)
    return rejected

# %%
# student two samples t-test
def student(triplogs_on, triplogs_off):
    rejected = []
    total = 0
    for idx in triplogs_on.index:
        if idx in triplogs_off.index:   
            total += 1
            pval = stats.ttest_ind(triplogs_on[idx], triplogs_off[idx], alternative='less').pvalue
            if pval < 0.05:
                # check same variance assumption (timings of two type of routes must have variance close to each other)
                s1 = np.sqrt(np.var(triplogs_on[idx], ddof=1))
                s2 = np.sqrt(np.var(triplogs_off[idx], ddof=1))
                valid = 'test valid'
                if np.abs(s1 - s2) > 50:
                    valid = 'test invalid'
#                 print(f'{idx} route is significally faster, {valid}, s1 {s1:.2f}, s2 {s2:.2f}')
                rejected.append(
                    (pval, idx)
                )
    print(len(rejected), 'of', total, 'rejected', len(rejected)/len(triplogs_on.index))
    return rejected

# %%
# next two funcs are not needed to reimplement
def plot_trips(triplogs_on, triplogs_off, rejected_idxs):
    fig, ax = plt.subplots(len(rejected_idxs), 1,figsize=(15,15), constrained_layout=True)
    for i, (pval, idx)  in enumerate(rejected_idxs):
        title = f'{", ".join(map(str, idx))}, pval {pval:.2f}'
        ax[i].set_title(title)
        ax[i].plot(triplogs_on[idx], label='on')
        ax[i].plot(triplogs_off[idx], label='off')
        ax[i].legend()

# %%
def make_df(rejected_idxs, groupby):
    df = [list(x)+[pval] for pval,x in rejected_idxs]
    df = pd.DataFrame(df)
    df.columns = groupby + ['pval']
    df = df.sort_values('pval')
    return df.reset_index(drop=True)

# %%
# groupby 
groupby = ['routename', 'direction', 'start', 'end']
# groupby = ['routename', 'direction', 'starthour']

segments_on = segments_df[segments_df.tspmode == True].groupby(groupby)['duration'].apply(list)

segments_off = segments_df[segments_df.tspmode == False].groupby(groupby)['duration'].apply(list)

# drop less that 3 obserationa
segments_off_idx = segments_off.apply(lambda x: len(x) > 3)
segments_off = segments_off[segments_off_idx]
print(segments_off.shape)

segments_on_idx = segments_on.apply(lambda x: len(x) > 3)
segments_on = segments_on[segments_on_idx]
print(segments_on.shape)
# Out:
# (13053,)
# (832,)

# %% [markdown]
# ### mann-whitney

# %%
# mann-whitney
rejected_idxs = mannwhitney(segments_on, segments_off)
# plot_trips(segments_on, segments_off, rejected_idxs)
make_df(rejected_idxs, groupby)
# Out:
# 29 of 703 rejected 0.041251778093883355
#    routename direction                           start  \
# 0         38  outbound          Geary Blvd & Laguna St
# 1         38  outbound       Market St & Montgomery St
# 2          8  outbound              4th St & Howard St
# 3         30  outbound         Chestnut St & Gough St:
# 4         38  outbound           Geary Blvd & Gough St
# 5       JBUS   inbound       Mission St & Appleton Ave
# 6         43  outbound     South Hill Blvd & Prague St
# 7         43   inbound         Geneva Ave & Madrid St:
# 8         38  outbound           Geary Blvd & 28th Ave
# 9          5  outbound        Mcallister St & Baker St
# 10      JBUS  outbound      Mission St & Appleton Ave:
# 11       14R  outbound           Mission St & 20th St:
# 12         8  outbound          Powell St & Filbert St
# 13        43   inbound         Geneva Ave & Cayuga Ave
# 14         5   inbound           Fulton St & 46th Ave:
# 15         9   inbound     Bayshore Blvd & Boutwell St
# 16        38  outbound          Market St & Sansome St
# 17        30  outbound           Sutter St & Kearny St
# 18        19   inbound       Rhode Island St & 16th St
# 19         8   inbound          Santos St & Geneva Ave
# 20         9   inbound             11th St & Market St
# 21       38R   inbound       Geary Blvd & Fillmore St:
# 22         9  outbound       San Bruno Ave & Felton St
# 23        19   inbound            Geary St & Larkin St
# 24         5   inbound   Mcallister St & Van Ness Ave:
# 25         8  outbound       Sunnydale Ave & Santos St
# 26        9R   inbound  Bayshore Blvd & Visitacion Ave
# 27         9  outbound         Market St & Stockton St
# 28        22  outbound           Fillmore St & Turk St
#
#                              end      pval
# 0        Geary Blvd & Webster St  0.001608
# 1           Geary St & Kearny St  0.003072
# 2             4th St & Folsom St  0.003497
# 3        Chestnut St & Laguna St  0.003799
# 4         Geary Blvd & Laguna St  0.007007
# 5           30th St & Dolores St  0.007146
# 6         Munich St & Geneva Ave  0.008281
# 7        Geneva Ave & Mission St  0.012463
# 8        Geary Blvd & Collins St  0.012591
# 9        Fulton St & Masonic Ave  0.013246
# 10     Diamond St & Bosworth St:  0.013455
# 11         Mission St & 24th St:  0.015352
# 12      Columbus Ave & Union St:  0.017757
# 13   Geneva Ave/Balboa Park BART  0.019402
# 14          Fulton St & 43rd Ave  0.026247
# 15  Bayshore Blvd & Cortland Ave  0.027737
# 16     Market St & Montgomery St  0.028951
# 17       Stockton St & Sutter St  0.032044
# 18    Rhode Island St & 15th St:  0.033513
# 19       Santos St & Velasco Ave  0.034584
# 20            Market St & 9th St  0.034935
# 21       Geary Blvd & Laguna St:  0.034977
# 22     San Bruno Ave & Bacon St:  0.038263
# 23             Polk St & Post St  0.040995
# 24      Mcallister St & Hyde St:  0.042291
# 25     Santos St & Brookdale Ave  0.044846
# 26    San Bruno Ave & Arleta Ave  0.046536
# 27           Market St & 5th  St  0.049391
# 28  Fillmore St & Mcallister St:  0.049806

# %% [markdown]
# ### student

# %%
# student
rejected_idxs = student(segments_on, segments_off)
# plot_trips(segments_on, segments_off, rejected_idxs)
make_df(rejected_idxs, groupby)
# Out:
# 29 of 703 rejected 0.03485576923076923
#    routename direction                             start  \
# 0         38  outbound         Market St & Montgomery St
# 1       JBUS   inbound         Mission St & Appleton Ave
# 2         38  outbound             Geary Blvd & 28th Ave
# 3          8  outbound       Visitacion Ave & Rutland St
# 4         38  outbound            Geary Blvd & Laguna St
# 5         38  outbound             Geary Blvd & Gough St
# 6         43  outbound       South Hill Blvd & Prague St
# 7          5  outbound          Mcallister St & Baker St
# 8         30  outbound           Chestnut St & Gough St:
# 9          9   inbound       Bayshore Blvd & Boutwell St
# 10        43   inbound           Geneva Ave & Cayuga Ave
# 11         5   inbound             Fulton St & 46th Ave:
# 12         9  outbound         San Bruno Ave & Felton St
# 13         8  outbound       Visitacion Ave & Britton St
# 14         8  outbound         Sunnydale Ave & Santos St
# 15         5   inbound     Mcallister St & Van Ness Ave:
# 16      JBUS  outbound        Mission St & Appleton Ave:
# 17       14R  outbound             Mission St & 20th St:
# 18         9   inbound               11th St & Market St
# 19        45   inbound       Stockton St & Columbus Ave:
# 20         8   inbound           Geneva Ave & Naples St:
# 21         5   inbound              Fulton St & 40th Ave
# 22       38R   inbound         Geary Blvd & Fillmore St:
# 23         8   inbound            Santos St & Geneva Ave
# 24        9R   inbound             11th St & Harrison St
# 25       38R   inbound  Geary Blvd & Park Presidio Blvd:
# 26         1  outbound         California St & Laurel St
# 27         1   inbound               Clay St & Powell St
# 28         1   inbound           Clay St & Montgomery St
#
#                              end      pval
# 0           Geary St & Kearny St  0.001107
# 1           30th St & Dolores St  0.005146
# 2        Geary Blvd & Collins St  0.006497
# 3   Visitacion Ave & Schwerin St  0.007385
# 4        Geary Blvd & Webster St  0.007929
# 5         Geary Blvd & Laguna St  0.010102
# 6         Munich St & Geneva Ave  0.011743
# 7        Fulton St & Masonic Ave  0.014807
# 8        Chestnut St & Laguna St  0.015306
# 9   Bayshore Blvd & Cortland Ave  0.016284
# 10   Geneva Ave/Balboa Park BART  0.016518
# 11          Fulton St & 43rd Ave  0.018165
# 12     San Bruno Ave & Bacon St:  0.025953
# 13    Visitacion Ave & Sawyer St  0.026615
# 14     Santos St & Brookdale Ave  0.026921
# 15      Mcallister St & Hyde St:  0.027845
# 16     Diamond St & Bosworth St:  0.028093
# 17         Mission St & 24th St:  0.030328
# 18            Market St & 9th St  0.030349
# 19    Stockton St & Pacific Ave:  0.031160
# 20        Geneva Ave & Munich St  0.033400
# 21          Fulton St & 37th Ave  0.042431
# 22       Geary Blvd & Laguna St:  0.043050
# 23       Santos St & Velasco Ave  0.044479
# 24  Bayshore Blvd & Cortland Ave  0.045430
# 25         Geary Blvd & 6th Ave:  0.046701
# 26     California St & Spruce St  0.048140
# 27         Clay St & Stockton St  0.049592
# 28          Clay St & Sansome St  0.049901

# %% [markdown]
# ## Grouping with the starthour

# %%
# groupby 
groupby = ['routename', 'direction', 'start', 'end', 'starthour']
# groupby = ['routename', 'direction', 'starthour']

segments_on = segments_df[segments_df.tspmode == True].groupby(groupby)['duration'].apply(list)

segments_off = segments_df[segments_df.tspmode == False].groupby(groupby)['duration'].apply(list)

# drop less that 3 obserationa
segments_off_idx = segments_off.apply(lambda x: len(x) > 3)
segments_off = segments_off[segments_off_idx]
print(segments_off.shape)

segments_on_idx = segments_on.apply(lambda x: len(x) > 3)
segments_on = segments_on[segments_on_idx]
print(segments_on.shape)
# Out:
# (14861,)
# (286,)

# %% [markdown]
# ### mann-whitney

# %%
# mann-whitney
rejected_idxs = mannwhitney(segments_on, segments_off)
# plot_trips(segments_on, segments_off, rejected_idxs)
make_df(rejected_idxs, groupby)
# Out:
# 4 of 107 rejected 0.037383177570093455
#   routename direction                            start  \
# 0        9R   inbound  Sunnydale Ave & Bay Shore Blvd:
# 1        38  outbound            Geary Blvd & 12th Ave
# 2        38  outbound            Geary Blvd & 12th Ave
# 3        54  outbound           Geneva Ave & Naples St
#
#                                end  starthour      pval
# 0   Bayshore Blvd & Visitacion Ave          1  0.020152
# 1  Geary Blvd & Park Presidio Blvd         15  0.030301
# 2  Geary Blvd & Park Presidio Blvd         19  0.047346
# 3          Geneva Ave & Madrid St:          2  0.047346

# %% [markdown]
# ### student

# %%
# student
rejected_idxs = student(segments_on, segments_off)
# plot_trips(segments_on, segments_off, rejected_idxs)
make_df(rejected_idxs, groupby)
# Out:
# 3 of 107 rejected 0.01048951048951049
#   routename direction                            start  \
# 0        9R   inbound  Sunnydale Ave & Bay Shore Blvd:
# 1         9   inbound       San Bruno Ave & Wayland St
# 2        38  outbound            Geary Blvd & 20th Ave
#
#                               end  starthour      pval
# 0  Bayshore Blvd & Visitacion Ave          1  0.021126
# 1        San Bruno Ave & Bacon St         15  0.049024
# 2           Geary Blvd & 22nd Ave          3  0.049978
